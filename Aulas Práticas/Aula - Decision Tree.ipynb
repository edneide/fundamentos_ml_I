# %% [markdown]
# # Imports

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [markdown]
# # Dados

# %%
df = pd.read_csv("diabetes.csv")
df.columns = df.columns.str.lower()
df.head()
# Out:
#    pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    diabetespedigreefunction  age  outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Separando os dados em features e target
X = df.drop('outcome', axis=1)
y = df['outcome']

# %%
# Dividindo os dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %% [markdown]
# # Modelo

# %%
# Definindo o modelo
modelo = DecisionTreeClassifier(max_depth=5, min_samples_split=10, min_samples_leaf=1, 
                               max_leaf_nodes=10)

# Treinando o modelo
fit = modelo.fit(X_train, y_train)

# Predições
y_pred = fit.predict(X_test)

# %%
# Avaliando o modelo
print("Acurácia do modelo: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# Acurácia do modelo:  0.7705627705627706

# %%
# Visualizando a árvore
from sklearn import tree
import pydotplus
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(30,30))
tree.plot_tree(fit, filled=True, rounded=True,
              feature_names=X_train.columns,
              class_names=['0', '1'],
              fontsize=12)
plt.show()

# %% [markdown]
# **-> Execício 1: variar os hiperparâmetros para ver se conseguimos melhorar a acurácia!!!**
# **-> Exercício 2: treinar uma árvore de decisão para os dados de cancer de mama**
